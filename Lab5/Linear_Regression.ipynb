# %% [markdown]
# <H1>Linear Regression</H1>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
advertisement_tv_influence = 2
base_salse = 5
random_scale= 5
num_smaples = 100

# %%
np.random.seed(40)

# %%
def plot_simple_linear_regression(x, y_true, y_pred, title  = 'Linear_Regression', xlabel = 'x', ylabel = 'y'):
    plt.scatter (x =x, y = y_true)
    plt.plot(x =x ,y = y_pred, 'g')
# Out:
#   Cell In[21], line 3
#     plt.plot(x =x ,y = y_pred, 'g')
#                                   ^
# SyntaxError: positional argument follows keyword argument

# %%
advertisement_tv = np.random.uniform(low = 0, high = 20, size = num_smaples)
sales_true = base_salse + advertisement_tv * advertisement_tv_influence + np.random.uniform(low = -random_scale, high = random_scale, size = num_smaples)

sales_pred = base_salse + advertisement_tv * advertisement_tv_influence

plot_simple_linear_regression(x = advertisement_tv, y_true = sales_true, y_pred = sales_pred, title = 'Sales vs Advertiesment(TV)', xlabel ='Advertisement Spending (in millions)', ylabel = 'Sales (in millions)')

# %%
x_mean =advertisement_tv.mean()
y_mean = sales_true.mean()
x = advertisement_tv
y = sales_true

beta1 = np.sum((x - x_mean) * (y - y_mean)) / np.sum((x - x_mean)**2)
beta0 = y_mean - beta1 * x_mean

print("Predicted TV influence : ", beta1)
print("Predicted Base Sales : ", beta0)
# Out:
# Predicted TV influence :  2.0321448666894937
# Predicted Base Sales :  4.546376330252226

# %% [markdown]
# <h2>Multiple Line Regression</h2>

# %%
advertisement2_tv_influence  = 2
advertisement2_radio_influence = 0.5
advertisement2_other_influence = 5
base_salse = 5
random_scale = 10
num_smaples = 20

advertisement2_radio = np.random.uniform(low = 0, high = 15, size = num_smaples)
advertisement2_tv = np.random.uniform(low =0, high = 20, size = num_smaples)
advertisement2_other = np.random.uniform(low = 0, high = 40 , size = num_smaples)

sales2_true = base_salse + advertisement2_tv * advertisement2_tv_influence + advertisement2_other * advertisement2_other_influence + advertisement2_radio * advertisement2_radio_influence + np.random.uniform(low= -random_scale, high= random_scale, size = num_smaples)

# %%
plt.scatter(advertisement2_radio, sales2_true)

# %%
plt.scatter(advertisement2_tv, sales2_true)

# %%
plt.scatter(advertisement2_other, sales2_true)

# %%
def get_regression_coeff
