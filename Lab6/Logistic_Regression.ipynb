# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy import random

# %% [markdown]
# Find the minimum value for $y = (x - 6)^2 + sin(3x)$ using gradient descent
# - Plot the graph of the function and the current value (x, y) at every ten steps
# - Try out different value for learning rate

# %%
def f(x):
    return (x-6)**2 + np.sin(x*5)

def df(x):
    return 2*(x-6) + 5*np.cos(x*5)

def min_at(start):
    x = start
    min_y = f(x)
    for i in range(1000):
        x = x - learning_rate*df(x)
        y = f(x)
        if y < min_y:
            min_y = y
            min_x = x
        plt.plot(x, y, 'ro')
    return start, min_x
learning_rate = 0.01

# %%
x = random.randint(-25,25)
min_x = x
for i in range(10):
    check_start, check_min_x = min_at(x)
    if f(check_min_x) < f(min_x):
        min_x = check_min_x
        min_start = check_start
    x = random.randint(-25,25)
print(min_x, f(min_x))
# Out:
# 8.257044597274028 4.664227099997193

# %%
x = np.arange(-10, 10, 0.1)
y = f(x)
plt.plot(x, y)

# %%
x= np.arange(-100, 100)
y = 1/ (1 + np.exp(-x))
plt.plot(x, y)

# %%
b0 = 0.01
b1 = 0.1
y = 1/ (1 + np.exp(-b0 - b1*x))
plt.plot(x, y)

# %%
def GRE(x):
    if x > 310:
        return 0
    else:
        return 1

# %%
x = np.random.randint(260, 340, 100)
y = np.array([GRE(i) for i in x])

# %%
i = random.randint(0,100, 5)
for k in i:
    y[k] = 1 - y[k]

# %%
plt.scatter(x, y)

# %%
x = np.arange(0.1, 10, 0.1)
y = np.log(x)
plt.plot(x, y)
