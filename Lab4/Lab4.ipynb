# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
netflix_data = pd.read_csv('netflix_title.csv')
imdb_data = pd.read_csv('imdb_rating.csv')

# %%
#View a portion of data at glance
#to find the format of data
netflix_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 show_id     type                  title  \
# 0             0           0      s1    Movie   Dick Johnson Is Dead
# 1             1           1      s2  TV Show          Blood & Water
# 2             2           2      s3  TV Show              Ganglands
# 3             3           3      s4  TV Show  Jailbirds New Orleans
# 4             4           4      s5  TV Show           Kota Factory
#
#           director                                               cast  \
# 0  Kirsten Johnson                                                NaN
# 1              NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Julien Leclercq  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3              NaN                                                NaN
# 4              NaN  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#
#          country          date_added rating   duration  \
# 0  United States  September 25, 2021  PG-13     90 min
# ...

# %%
netflix_data.tail()
# Out:
#       Unnamed: 0.1  Unnamed: 0 show_id     type        title         director  \
# 8802          8802        8802   s8803    Movie       Zodiac    David Fincher
# 8803          8803        8803   s8804  TV Show  Zombie Dumb              NaN
# 8804          8804        8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805          8805        8805   s8806    Movie         Zoom     Peter Hewitt
# 8806          8806        8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added rating   duration  \
# ...

# %%
netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  8807 non-null   int64
#  1   Unnamed: 0    8807 non-null   int64
#  2   show_id       8807 non-null   object
#  3   type          8807 non-null   object
#  4   title         8807 non-null   object
#  5   director      6173 non-null   object
#  6   cast          7982 non-null   object
#  7   country       7976 non-null   object
#  8   date_added    8797 non-null   object
#  9   rating        8803 non-null   object
#  10  duration      8804 non-null   object
#  11  listed_in     8807 non-null   object
#  12  description   8807 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 894.6+ KB

# %%
imdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %%
#finding number of null valuse
print("Netflix data shape : ", netflix_data.shape)
print(netflix_data.isna().sum())
#.isna() return a grid of data where NaN is repalce with true and where data is present is replace with false. true = 1 , flase = 0
#.sum() returns sum of data at each column
# Out:
# Netflix data shape :  (8807, 13)
# Unnamed: 0.1       0
# Unnamed: 0         0
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
print("Imdb data set shape : ", imdb_data.shape)
print(imdb_data.isna().sum())
# Out:
# Imdb data set shape :  (9999, 9)
# MOVIES         0
# YEAR         644
# GENRE         80
# RATING      1820
# ONE-LINE       0
# STARS          0
# VOTES       1820
# RunTime     2958
# Gross       9539
# dtype: int64

# %%
#columns that are not needed are removed
netflix_data.drop(columns= ['show_id', 'cast', 'date_added', 'duration', 'description', 'listed_in', 'Unnamed: 0.1', 'Unnamed: 0'], inplace = True)
imdb_data.drop(columns= ['ONE-LINE', 'STARS', 'RunTime', 'Gross'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
#       1 #columns that are not needed are removed
# ----> 2 netflix_data.drop(columns= ['show_id', 'cast', 'date_added', 'duration', 'description', 'listed_in', 'Unnamed: 0.1', 'Unnamed: 0'], inplace = True)
#       3 imdb_data.drop(columns= ['ONE-LINE', 'STARS', 'RunTime', 'Gross'], inplace = True)
#
# File ~/Documents/Pulchock-BCT/Sem3/DataScienceLab/Lab4/.venv/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
# ...

# %%
netflix_data.head()
# Out:
#       type                  title         director        country rating
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States  PG-13
# 1  TV Show          Blood & Water              NaN   South Africa  TV-MA
# 2  TV Show              Ganglands  Julien Leclercq            NaN  TV-MA
# 3  TV Show  Jailbirds New Orleans              NaN            NaN  TV-MA
# 4  TV Show           Kota Factory              NaN          India  TV-MA

# %%
imdb_data.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE  RATING    VOTES
# 0      \nAction, Horror, Thriller                 6.1   21,062
# 1  \nAnimation, Action, Adventure                 5.0   17,870
# 2       \nDrama, Horror, Thriller                 8.2  885,805
# 3  \nAnimation, Adventure, Comedy                 9.2  414,849
# 4         \nAction, Crime, Horror                 NaN      NaN

# %%
#Remove dublicate 
# imdb_data.duplicated(subset=['MOVIES']).sum()
imdb_data[imdb_data.duplicated(subset=['MOVIES'],keep='first')].sort_values(by= 'MOVIES', ascending=False)
#Wednesday only one why show for that there is another parameter
#imdb_data[imdb_data.duplicated(subset=['MOVIES'],keep = False/first(defult)/last)].sort_values(by= 'MOVIES', ascending=False)
# Out:
#                MOVIES             YEAR  \
# 5460       Wanderlust  (2006 TV Movie)
# 3772         Verónica      (II) (2017)
# 5454  The Whole Truth           (2009)
# 2060     The Stranger           (1946)
# 5374      The Silence     (III) (2015)
# ...               ...              ...
# 7789   13 Reasons Why      (2017–2020)
# 8376   13 Reasons Why      (2017–2020)
# 7423   13 Reasons Why      (2017–2020)
# 8375   13 Reasons Why      (2017–2020)
# 8134   13 Reasons Why      (2017–2020)
#
#                                        GENRE  RATING   VOTES
# 5460      \nDocumentary, History                 6.6     122
# 3772  \nDrama, Mystery, Thriller                 5.9   1,342
# 5454            \nAction, Comedy                 3.2     114
# 2060   \nCrime, Drama, Film-Noir                 7.4  25,188
# 5374                     \nDrama                 7.3     298
# ...                                      ...     ...     ...
# ...

# %%
imdb_data.drop_duplicates(inplace=True)

# %%
imdb_data.dropna(how='any',inplace=True)
netflix_data.dropna(how='any',inplace=True)

# %%
imdb_data.isna().sum()
# Out:
# MOVIES    0
# YEAR      0
# GENRE     0
# RATING    0
# VOTES     0
# dtype: int64

# %%
imdb_data['Year_released'] = imdb_data['YEAR'].str.split('-').str[0].str[1:5]

# %%
imdb_data.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 5                          Outer Banks     (2020– )
#
#                                         GENRE  RATING    VOTES Year_released
# 0      \nAction, Horror, Thriller                 6.1   21,062          2021
# 1  \nAnimation, Action, Adventure                 5.0   17,870          2021
# 2       \nDrama, Horror, Thriller                 8.2  885,805          2010
# 3  \nAnimation, Adventure, Comedy                 9.2  414,849          2013
# 5          \nAction, Crime, Drama                 7.6   25,858          2020

# %%
imdb_data['YEAR'].unique()
# Out:
# array(['(2021)', '(2021– )', '(2010–2022)', '(2013– )', '(2020– )',
#        '(2006–2013)', '(2019– )', '(2016–2021)', '(2011– )', '(2005– )',
#        '(2008–2013)', '(2017– )', '(2017–2021)', '(2016– )',
#        '(1994–2004)', '(2014– )', '(2013–2020)', '(2015– )',
#        '(2005–2020)', '(2013–2022)', '(2003– )', '(2009–2020)',
#        '(I) (2018– )', '(2010–2015)', '(2011–2019)', '(2015–2020)',
#        '(2005–2014)', '(2009–2015)', '(2008–2014)', '(2016–2018)',
#        '(2009–2017)', '(2020)', '(2018–2021)', '(2017–2020)',
#        '(1987–1994)', '(2018– )', '(2012– )', '(2014–2020)',
#        '(2011–2018)', '(2005–2017)', '(2017)', '(2007–2015)',
#        '(2000–2007)', '(II) (2007– )', '(1993)', '(1999–2022)',
#        '(2015–2018)', '(2014–2019)', '(2016)', '(2012–2020)',
#        '(2013–2019)', '(2007–2012)', '(2011–2020)', '(2010–2017)',
#        '(2000–2015)', '(2015–2021)', '(2001)', '(1997– )', '(2011–2017)',
# ...

# %%
#aaile paxi geram la
#imdb_data['Year_released'] = imdb_data['YEAR'].str.split('-').str[0].repalce(r'[^/d]', regex = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4714/1662592810.py in ?()
# ----> 1 imdb_data['Year_released'] = imdb_data['YEAR'].str.split('-').str[0].repalce(r'[^/d]', regex = True)
#
# ~/Documents/Pulchock-BCT/Sem3/DataScienceLab/Lab4/.venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'repalce'

# %% [markdown]
# Merge more important
